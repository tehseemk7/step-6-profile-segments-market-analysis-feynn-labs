# %%
import pandas as pd

# %%
import numpy as np

# %%
np.random.seed(0)

# %%
df = pd.DataFrame({'Feature1': np.random.rand(300),
    'Feature2': np.random.rand(300),
    'Cluster': np.random.randint(0, 4, 300)
})

# %%
segment_means = df.groupby('Cluster').mean()

# %%
print("Key Characteristics of Market Segments:")
# Out:
# Key Characteristics of Market Segments:

# %%
print(segment_means)
# Out:
#          Feature1  Feature2
# Cluster
# 0        0.465132  0.482984
# 1        0.478061  0.488087
# 2        0.539157  0.472315
# 3        0.530939  0.523580

# %%
segment_summary = df.groupby('Cluster').agg(['mean', 'std', 'min', 'max'])

# %%
print("Traditional Profiling Summary:")
# Out:
# Traditional Profiling Summary:

# %%
print(segment_summary)
# Out:
#          Feature1                                Feature2                      \
#              mean       std       min       max      mean       std       min
# Cluster
# 0        0.465132  0.260203  0.025663  0.963663  0.482984  0.295484  0.011427
# 1        0.478061  0.271921  0.016430  0.981829  0.488087  0.291355  0.007884
# 2        0.539157  0.304002  0.011714  0.978618  0.472315  0.302241  0.002703
# 3        0.530939  0.318414  0.004695  0.998847  0.523580  0.301187  0.012036
#
#
#               max
# Cluster
# 0        0.997962
# 1        0.992011
# 2        0.994401
# 3        0.989410

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12, 6))

# %%
sns.barplot(x='Cluster', y='Feature1', data=df, estimator=np.mean, ci=None, palette='viridis')
# Out:
# C:\Users\tehse\AppData\Local\Temp\ipykernel_33748\794819775.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Cluster', y='Feature1', data=df, estimator=np.mean, ci=None, palette='viridis')
# C:\Users\tehse\AppData\Local\Temp\ipykernel_33748\794819775.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Cluster', y='Feature1', data=df, estimator=np.mean, ci=None, palette='viridis')
# <Axes: xlabel='Cluster', ylabel='Feature1'>

# %%
plt.title('Mean of Feature1 by Cluster')
# Out:
# Text(0.5, 1.0, 'Mean of Feature1 by Cluster')

# %%
plt.xlabel('Cluster')
# Out:
# Text(0.5, 0, 'Cluster')

# %%
plt.ylabel('Mean of Feature1')
# Out:
# Text(0, 0.5, 'Mean of Feature1')

# %%
plt.show()

# %%
plt.figure(figsize=(12, 6))

# %%
sns.boxplot(x='Cluster', y='Feature1', data=df, palette='viridis')
# Out:
# C:\Users\tehse\AppData\Local\Temp\ipykernel_33748\1298818123.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Cluster', y='Feature1', data=df, palette='viridis')
# <Axes: xlabel='Cluster', ylabel='Feature1'>

# %%
plt.title('Box Plot of Feature1 by Cluster')
# Out:
# Text(0.5, 1.0, 'Box Plot of Feature1 by Cluster')

# %%
plt.xlabel('Cluster')
# Out:
# Text(0.5, 0, 'Cluster')

# %%
plt.ylabel('Feature1')
# Out:
# Text(0, 0.5, 'Feature1')

# %%
plt.show()

# %%
from sklearn.decomposition import PCA
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 from sklearn.decomposition import PCA
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
import sys

# %%
sys.path.append("C:/Users/tehse/AppData/Roaming/Python/Python312/site-packages")

# %%
from sklearn.cluster import KMeans

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
X_pca = pca.fit_transform(df[['Feature1', 'Feature2']])

# %%
kmeans = KMeans(n_clusters=4, random_state=0)

# %%
clusters = kmeans.fit_predict(X_pca)

# %%
plot_df = pd.DataFrame(X_pca, columns=['PC1', 'PC2'])

# %%
plot_df['Cluster'] = clusters

# %%
plt.figure(figsize=(12, 8))
# Out:
# Figure(1200x800)

# %%
sns.scatterplot(x='PC1', y='PC2', hue='Cluster', data=plot_df, palette='viridis', s=100, alpha=0.7)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
centroids = pca.transform(kmeans.cluster_centers_)

# %%
plt.scatter(centroids[:, 0], centroids[:, 1], s=300, c='red', marker='X', label='Centroids')

# %%
plt.title('Segment Separation Plot')
# Out:
# Text(0.5, 1.0, 'Segment Separation Plot')

# %%
plt.xlabel('Principal Component 1')
# Out:
# Text(0.5, 0, 'Principal Component 1')

# %%
plt.ylabel('Principal Component 2')
# Out:
# Text(0, 0.5, 'Principal Component 2')

# %%
plt.legend()
# Out:
# Legend

# %%
plt.show()

# %%
deprecated
# Out:
# Traceback (most recent call last):
#   File "c:\Users\tehse\.vscode\extensions\ms-python.python-2024.13.2024082701-win32-x64\python_files\python_server.py", line 130, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# NameError: name 'deprecated' is not defined

# %%
from some_library import deprecated
# Out:
# Traceback (most recent call last):
#   File "c:\Users\tehse\.vscode\extensions\ms-python.python-2024.13.2024082701-win32-x64\python_files\python_server.py", line 130, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# ModuleNotFoundError: No module named 'some_library'

# %%
import sys

# %%
sys.path.append("C:/Users/tehse/AppData/Roaming/Python/Python312/site-packages")

# %%
from sklearn.cluster import KMeans

# %%
def checklist():
    tasks = [
        "Use the selected segments from Step 5.",
        "Visualise segment profiles to learn about what makes each segment distinct.",
        "Use knock-out criteria to check if any of the segments currently under consideration should be eliminated.",
        "Pass on the remaining segments to Step 7 for describing."
    ]

# %%
print("Step 6 Checklist:")
# Out:
# Step 6 Checklist:

# %%
deprecated
# Out:
# Traceback (most recent call last):
#   File "c:\Users\tehse\.vscode\extensions\ms-python.python-2024.13.2024082701-win32-x64\python_files\python_server.py", line 130, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# NameError: name 'deprecated' is not defined

# %%
deprecated
# Out:
# Traceback (most recent call last):
#   File "c:\Users\tehse\.vscode\extensions\ms-python.python-2024.13.2024082701-win32-x64\python_files\python_server.py", line 130, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# NameError: name 'deprecated' is not defined

# %%
print("Step 6 Checklist:")
# Out:
# Step 6 Checklist:

# %%
def checklist():
    tasks = [
        "Use the selected segments from Step 5.",
        "Visualise segment profiles to learn about what makes each segment distinct.",
        "Use knock-out criteria to check if any of the segments currently under consideration should be eliminated.",
        "Pass on the remaining segments to Step 7 for describing."
    ]
    print("Step 6 Checklist:")
    for task in tasks:
        response = input(f"Has the task '{task}' been completed? (yes/no): ")

# %%
def checklist():
    tasks = [
        "Use the selected segments from Step 5.",
        "Visualise segment profiles to learn about what makes each segment distinct.",
        "Use knock-out criteria to check if any of the segments currently under consideration should be eliminated.",
        "Pass on the remaining segments to Step 7 for describing."
    ]
    print("Step 6 Checklist:")
    for task in tasks:
        response = input(f"Has the task '{task}' been completed? (yes/no): ")
        if response.lower() == 'yes':
            print(f"Task '{task}' completed.")

# %%
deprecated
# Out:
# Traceback (most recent call last):
#   File "c:\Users\tehse\.vscode\extensions\ms-python.python-2024.13.2024082701-win32-x64\python_files\python_server.py", line 130, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# NameError: name 'deprecated' is not defined

# %%
deprecated
# Out:
# Traceback (most recent call last):
#   File "c:\Users\tehse\.vscode\extensions\ms-python.python-2024.13.2024082701-win32-x64\python_files\python_server.py", line 130, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# NameError: name 'deprecated' is not defined

# %%
deprecated
# Out:
# Traceback (most recent call last):
#   File "c:\Users\tehse\.vscode\extensions\ms-python.python-2024.13.2024082701-win32-x64\python_files\python_server.py", line 130, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# NameError: name 'deprecated' is not defined

# %%
print("Step 6 Checklist:")
# Out:
# Step 6 Checklist:

# %%
tasks = ['task1', 'task2', 'task3']

# %%
deprecated
# Out:
# Traceback (most recent call last):
#   File "c:\Users\tehse\.vscode\extensions\ms-python.python-2024.13.2024082701-win32-x64\python_files\python_server.py", line 130, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# NameError: name 'deprecated' is not defined

# %%
def checklist():
    tasks = [
        "Use the selected segments from Step 5.",
        "Visualise segment profiles to learn about what makes each segment distinct.",
        "Use knock-out criteria to check if any of the segments currently under consideration should be eliminated.",
        "Pass on the remaining segments to Step 7 for describing."
    ]
    print("Step 6 Checklist:")
    tasks = ['task1', 'task2', 'task3']
    task_status = {
    'task1': 'completed',
    'task2': 'pending',
    'task3': 'completed'
}

# %%
deprecated
# Out:
# Traceback (most recent call last):
#   File "c:\Users\tehse\.vscode\extensions\ms-python.python-2024.13.2024082701-win32-x64\python_files\python_server.py", line 130, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# NameError: name 'deprecated' is not defined

# %%
deprecated
# Out:
# Traceback (most recent call last):
#   File "c:\Users\tehse\.vscode\extensions\ms-python.python-2024.13.2024082701-win32-x64\python_files\python_server.py", line 130, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# NameError: name 'deprecated' is not defined

# %%
deprecated
# Out:
# Traceback (most recent call last):
#   File "c:\Users\tehse\.vscode\extensions\ms-python.python-2024.13.2024082701-win32-x64\python_files\python_server.py", line 130, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# NameError: name 'deprecated' is not defined

# %%
deprecated
# Out:
# Traceback (most recent call last):
#   File "c:\Users\tehse\.vscode\extensions\ms-python.python-2024.13.2024082701-win32-x64\python_files\python_server.py", line 130, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# NameError: name 'deprecated' is not defined

# %%
deprecated
# Out:
# Traceback (most recent call last):
#   File "c:\Users\tehse\.vscode\extensions\ms-python.python-2024.13.2024082701-win32-x64\python_files\python_server.py", line 130, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# NameError: name 'deprecated' is not defined

# %%
deprecated
# Out:
# Traceback (most recent call last):
#   File "c:\Users\tehse\.vscode\extensions\ms-python.python-2024.13.2024082701-win32-x64\python_files\python_server.py", line 130, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# NameError: name 'deprecated' is not defined

# %%
def checklist():
    tasks = [
        "Use the selected segments from Step 5.",
        "Visualise segment profiles to learn about what makes each segment distinct.",
        "Use knock-out criteria to check if any of the segments currently under consideration should be eliminated.",
        "Pass on the remaining segments to Step 7 for describing."
    ]
    print("Step 6 Checklist:")
    tasks = ['task1', 'task2', 'task3']
    task_status = {
    'task1': 'completed',
    'task2': 'pending',
    'task3': 'completed'
}
    for task in tasks:
        response = input(f"Has the task '{task}' been completed? (yes/no): ")

# %%
def checklist():
    tasks = [
        "Use the selected segments from Step 5.",
        "Visualise segment profiles to learn about what makes each segment distinct.",
        "Use knock-out criteria to check if any of the segments currently under consideration should be eliminated.",
        "Pass on the remaining segments to Step 7 for describing."
    ]
    print("Step 6 Checklist:")
    tasks = ['task1', 'task2', 'task3']
    task_status = {
    'task1': 'completed',
    'task2': 'pending',
    'task3': 'completed'
}
    for task in tasks:
        response = input(f"Has the task '{task}' been completed? (yes/no): ")
        if response.lower() == 'yes':
            print(f"Task '{task}' completed.")

# %%
def checklist():
    tasks = [
        "Use the selected segments from Step 5.",
        "Visualise segment profiles to learn about what makes each segment distinct.",
        "Use knock-out criteria to check if any of the segments currently under consideration should be eliminated.",
        "Pass on the remaining segments to Step 7 for describing."
    ]
    print("Step 6 Checklist:")
    tasks = ['task1', 'task2', 'task3']
    task_status = {
    'task1': 'completed',
    'task2': 'pending',
    'task3': 'completed'
}
    for task in tasks:
        response = input(f"Has the task '{task}' been completed? (yes/no): ")
        if response.lower() == 'yes':
            print(f"Task '{task}' completed.")
        else:
            print(f"Task '{task}' is pending.")

# %%
checklist()
# Out:
# Step 6 Checklist:
# Task 'task1' is pending.
# Task 'task2' is pending.
# Task 'task3' is pending.
